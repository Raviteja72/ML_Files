# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

import cv2

# %%
img = cv2.imread('jack_dorsey.jpg')

plt.imshow(img)

# %%
img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)

plt.figure(figsize=(12,8))


plt.imshow(img)

# %%
img.shape
# Out:
# (900, 1600, 3)

# %%
img_gray = cv2.imread('jack_dorsey.jpg',cv2.IMREAD_GRAYSCALE)

img_gray.shape
plt.figure(figsize=(12,8))
plt.imshow(img_gray)

# %%
plt.figure(figsize=(12,8))
plt.imshow(img_gray,cmap='gray')

# %%
plt.figure(figsize=(12,8))
plt.imshow(img_gray,cmap='coolwarm')

# %%
img_new = cv2.resize(img,(1440,1080))
plt.figure(figsize=(12,8))
plt.imshow(img_new)

# %%
w_ratio = 0.5
h_ratio = 0.5
re_img = cv2.resize(img,(0,0),img,w_ratio,h_ratio)

# %%
plt.imshow(re_img)
re_img.shape
# Out:
# (450, 800, 3)

# %%
img_1 = cv2.flip(img,0)
plt.figure(figsize=(6,8))
plt.imshow(img_1)

# %%
img_1 = cv2.flip(img,1)
plt.figure(figsize=(6,8))
plt.imshow(img_1)

# %%
img_1 = cv2.flip(img,-1)
plt.figure(figsize=(6,8))
plt.imshow(img_1)

# %%
cv2.imwrite('totally_new1.jpg',img_new)
# Out:
# True

# %%
fig = plt.figure(figsize=(12,6))
ax = fig.add_subplot(111)
ax.imshow(img_new)

# %%
pic = cv2.imread('jack_dorsey.jpg')
pic.shape
# Out:
# (900, 1600, 3)

# %%
pic1 = cv2.imread('jack_dorsey.jpg')

# %%
plt.imshow(pic1)

# %%
pic1 = cv2.resize(pic1,(2160,1080))
#pic1 = cv2.cvtColor(pic1,cv2.COLOR_BGR2RGB)

# %%
pic1 = cv2.cvtColor(pic1,cv2.COLOR_BGR2RGB)
plt.figure(figsize=(12,6))
plt.imshow(pic1)

# %%
cv2.imwrite('jack1.jpg',pic1)
# Out:
# True

# %%
''' imgs = cv2.imread('jack_dorsey_CEO.jpg')

cv2.imshow('puppy',imgs)

cv2.waitKey() '''
# Out:
# " imgs = cv2.imread('jack_dorsey_CEO.jpg')\n\ncv2.imshow('puppy',imgs)\n\ncv2.waitKey() "
