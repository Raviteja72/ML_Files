# %% [markdown]
# # NumPy and Image Assessment
#
# **COMPLETE THE TASKS IN BOLD BELOW.**

# %% [markdown]
# **TASK: Import NumPy**

# %%
import numpy as np

# %% [markdown]
# **TASK: Create a 5 by 5 array where every number is a 10**

# %%
arr = np.zeros((5,5)) + 10
arr
# Out:
# array([[10., 10., 10., 10., 10.],
#        [10., 10., 10., 10., 10.],
#        [10., 10., 10., 10., 10.],
#        [10., 10., 10., 10., 10.],
#        [10., 10., 10., 10., 10.]])

# %% [markdown]
# **TASK: Run the cell below to create an array of random numbers and see if you can figure out how it works.**

# %%
# This line sets a "seed" so you get the same random numbers we do
np.random.seed(101)
# This line creates an array of random numbers
arr = np.random.randint(low=0,high=100,size=(5,5))

# %% [markdown]
# **TASK: What are the largest and smalled values in this array?**

# %%
arr.max()
# Out:
# 95

# %%
arr.min()
# Out:
# 4

# %% [markdown]
# **TASK: Use PIL and matplotlib to read and display the ../DATA/00-puppy.jpg image.**

# %%
ls
# Out:
# 03-Numpy-and-Image-Assessment.ipynb
# 04-Numpy-and-Image-Assessment-Solution.ipynb
# 47571280192_beb5caed48_h-e1555441528912.jpg
# ANN.ipynb
# CAT VS DOG.ipynb
# CATS VS DOGS 1.ipynb
# CATS VS DOGS 2.ipynb
# CATS VS DOGS 3.ipynb
# CNN.ipynb
# DIGIT_RECOGNITION.ipynb
# IMAGE_CLASSIFIER.ipynb
# MNIST_CNN.ipynb*
# MOVIE_REVIEW.ipynb
# Untitled.ipynb
# cats vs dogs.ipynb
# cats_and_dogs_filtered/
# image.ipynb
# test/
# test_data.npy
# train_data.npy

# %%
from PIL import Image

arr1 = Image.open('JACK.jpg')

arr1
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=247x204 at 0x7F8E3C6FE110>

# %% [markdown]
# **TASK: Convert the image to a NumPy Array**

# %%
arr1 = np.asarray(arr1)

# %% [markdown]
# **FINAL TASK: Use slicing to set the RED and GREEN channels of the picture to 0, then use imshow() to show the isolated blue channel**

# %%
arr1.shape
# Out:
# (204, 247, 3)

# %%
arr2 = arr1.copy()
arr2[:,:,1] = 0
arr2[:,:,2] = 0
import matplotlib.pyplot as plt
# %matplotlib inline
plt.imshow(arr2)

# %%
arr3 = arr1.copy()
arr3[:,:,0] = 0
arr3[:,:,1] = 0
plt.imshow(arr3)

# %%
arr4 = arr1.copy()
arr4[:,:,0] = 0
arr4[:,:,2] = 0
plt.imshow(arr4)

# %% [markdown]
# ## Great Job!

# %% [markdown]
# ----
